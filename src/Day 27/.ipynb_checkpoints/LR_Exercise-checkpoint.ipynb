# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model

# %%
df=pd.read_csv("canada_per_capita_income.csv")
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plt.title("Year Vs PCI($)")
plt.xlabel("year")
plt.ylabel('per capita income (US$)')
plt.scatter(df.year,df['per capita income (US$)'],color="red",marker='+')
plt.show()

# %%
year=df.drop('per capita income (US$)',axis=1)
year.head()
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
pci=df['per capita income (US$)']
pci.head()
# Out:
# 0    3399.299037
# 1    3768.297935
# 2    4251.175484
# 3    4804.463248
# 4    5576.514583
# Name: per capita income (US$), dtype: float64

# %%
reg=linear_model.LinearRegression()
reg.fit(year,pci)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# C:\Users\adith\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
plt.title("Linear Regression (Year Vs PCI($))")
plt.xlabel("year")
plt.ylabel('per capita income (US$)')
plt.scatter(year,pci)
plt.plot(year,reg.predict(year),color='red')
plt.show()

# %%
for i in range(2020,2031):
    print(f"{i}: {reg.predict([[i]])}")
# Out:
# 2020: [41288.69409442]
# 2021: [42117.15916964]
# 2022: [42945.62424486]
# 2023: [43774.08932009]
# 2024: [44602.55439531]
# 2025: [45431.01947053]
# 2026: [46259.48454575]
# 2027: [47087.94962098]
# 2028: [47916.4146962]
# 2029: [48744.87977142]
# 2030: [49573.34484664]
# C:\Users\adith\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\adith\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\adith\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...
